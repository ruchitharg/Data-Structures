# %%
# 1. Generate a list of 100 integers containing values between 90 to 130 and store it in the variable `int_list`. After generating the list, find the following:

import random

# Generate a list of 100 integers containing values between 90 to 130
int_list = [random.randint(90, 130) for _ in range(100)]
int_list
# Out:
# [108,
#  91,
#  91,
#  119,
#  122,
#  102,
#  92,
#  126,
#  120,
#  103,
#  98,
#  103,
#  113,
#  102,
#  93,
#  93,
#  123,
#  107,
#  110,
#  110,
#  109,
#  107,
#  107,
#  105,
#  101,
#  94,
#  102,
#  105,
#  101,
#  116,
#  106,
#  98,
#  129,
#  102,
#  104,
#  127,
#  121,
#  95,
#  112,
#  119,
#  127,
#  119,
#  101,
#  99,
#  100,
#  115,
#  123,
#  103,
#  129,
#  90,
#  96,
#  121,
#  121,
#  121,
#  123,
#  100,
#  101,
#  124,
#  115,
#  119,
#  116,
#  130,
#  115,
#  97,
#  109,
#  113,
#  107,
#  122,
#  90,
#  92,
#  111,
#  113,
#  96,
#  100,
#  130,
#  112,
#  116,
#  113,
#  119,
#  95,
#  107,
#  128,
#  113,
#  90,
#  119,
#  104,
#  122,
#  99,
#  121,
#  107,
#  114,
#  129,
#  116,
#  114,
#  113,
#  117,
#  109,
#  105,
#  129,
#  130]

# %%
# (i) Write a Python function to calculate the mean of a given list of numbers. Create a function to find the median of a list of numbers.

def calculate_mean(numbers):
    return sum(numbers) / len(numbers)

# Example usage:
int_list = [random.randint(90, 130) for _ in range(100)]
mean_value = calculate_mean(int_list)
print("Mean:", mean_value)

def calculate_median(numbers):
    sorted_numbers = sorted(numbers)
    n = len(sorted_numbers)
    mid = n // 2

    if n % 2 == 0:
        median = (sorted_numbers[mid - 1] + sorted_numbers[mid]) / 2
    else:
        median = sorted_numbers[mid]

    return median

# Example usage:
median_value = calculate_median(int_list)
print("Median:", median_value)
# Out:
# Mean: 111.28
# Median: 111.5

# %%
# (ii) Develop a program to compute the mode of a list of integers.

from collections import Counter

def find_mode(int_list):
    # Count the frequency of each integer in the list
    count = Counter(int_list)
    
    # Find the maximum frequency
    max_count = max(count.values())
    
    # Find the integer(s) with the maximum frequency
    mode = [key for key, value in count.items() if value == max_count]
    
    return mode

# Example usage with a list of integers
int_list = [random.randint(90, 130) for _ in range(100)]  # Replace with your list
mode = find_mode(int_list)
print("Mode of the list:", mode)
# Out:
# Mode of the list: [129, 107]

# %%
# (iii) Implement a function to calculate the weighted mean of a list of values and their corresponding weights.

def weighted_mean(values, weights):
    if len(values) != len(weights):
        raise ValueError("The length of values and weights must be the same.")
    weighted_sum = sum(value * weight for value, weight in zip(values, weights))
    total_weight = sum(weights)
    return weighted_sum / total_weight if total_weight != 0 else 0

# Example usage:
values = [90, 100, 110]
weights = [1, 2, 3]
result = weighted_mean(values, weights)
print("Weighted Mean:", result)
# Out:
# Weighted Mean: 103.33333333333333

# %%
# (iv) Write a Python function to find the geometric mean of a list of positive numbers.

import math
from functools import reduce

def geometric_mean(nums):
    if len(nums) == 0:
        return 0
    
    # Ensure all numbers are positive
    if any(n <= 0 for n in nums):
        raise ValueError("All numbers must be positive to compute the geometric mean.")
    
    product = reduce(lambda x, y: x * y, nums)
    return math.pow(product, 1/len(nums))

# Example usage:
geom_mean = geometric_mean(int_list)
print("Geometric Mean:", geom_mean)
# Out:
# Geometric Mean: 109.32998132537976

# %%
# (v) Create a program to calculate the harmonic mean of a list of values.

def harmonic_mean(values):
    # Ensure the list is not empty to avoid division by zero
    if len(values) == 0:
        return 0
    
    # Calculate the harmonic mean
    n = len(values)
    sum_reciprocal = sum(1 / value for value in values)
    return n / sum_reciprocal

# Example usage with the previously generated int_list
int_list = [random.randint(90, 130) for _ in range(100)]
harmonic_mean_value = harmonic_mean(int_list)
print("Harmonic Mean:", harmonic_mean_value)
# Out:
# Harmonic Mean: 107.89014353824234

# %%
# (vi) Build a function to determine the midrange of a list of numbers (average of the minimum and maximum).

import random

# Step 1: Generate the list of 100 integers between 90 and 130
int_list = [random.randint(90, 130) for _ in range(100)]

# Step 2: Build a function to determine the midrange of a list of numbers
def midrange(numbers):
    return (min(numbers) + max(numbers)) / 2

# Calculate the midrange of int_list
midrange_value = midrange(int_list)

int_list, midrange_value
# Out:
# ([127,
#   108,
#   120,
#   115,
#   97,
#   108,
#   106,
#   91,
#   102,
#   127,
#   104,
#   103,
#   116,
#   127,
#   124,
#   101,
#   116,
#   102,
#   94,
#   98,
#   111,
#   125,
#   113,
#   97,
#   103,
#   96,
#   126,
#   121,
#   107,
#   104,
#   92,
#   123,
#   90,
#   90,
#   125,
#   105,
#   122,
#   96,
#   116,
#   116,
#   104,
#   110,
#   110,
#   104,
#   113,
#   92,
#   103,
#   108,
#   115,
#   118,
#   124,
#   92,
#   93,
#   96,
#   119,
#   97,
#   122,
#   101,
#   93,
#   99,
#   104,
#   129,
#   109,
#   99,
#   124,
#   107,
#   99,
#   107,
#   111,
#   116,
#   97,
#   107,
#   101,
#   129,
#   128,
#   117,
#   108,
#   96,
#   110,
#   104,
#   120,
#   109,
#   118,
#   130,
#   94,
#   106,
#   98,
#   129,
#   95,
#   91,
#   104,
#   129,
#   101,
#   101,
#   110,
#   96,
#   104,
#   106,
#   121,
#   124],
#  110.0)

# %%
# (vii) Implement a Python program to find the trimmed mean of a list, excluding a certain percentage of outliers.

import numpy as np

def trimmed_mean(data, trim_percent):
    if not 0 <= trim_percent < 50:
        raise ValueError("trim_percent must be between 0 and 50")
        
    n = len(data)
    k = int(n * trim_percent / 100)
    
    trimmed_data = sorted(data)[k:n-k]
    return np.mean(trimmed_data)

# Example usage
int_list = [random.randint(90, 130) for _ in range(100)]
trim_percent = 10  # Exclude the lowest 10% and highest 10%
result = trimmed_mean(int_list, trim_percent)

print(f"Trimmed mean with {trim_percent}% trimming is {result:.2f}")
# Out:
# Trimmed mean with 10% trimming is 108.74

# %%
# 2. Generate a list of 500 integers containing values between 200 to 300 and store it in the variable `int_list2`. After generating the list, find the following:
# (i) Compare the given list of visualization for the given data:
# 1. Frequency & Gaussian distribution
# 2. Frequency smoothened KDE plot
# 3. Gaussian distribution & smoothened KDE plot

import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

# Step 1: Generate the list of 500 integers between 200 and 300
int_list2 = [random.randint(200, 300) for _ in range(500)]

# Step 2: Visualizations

# Frequency & Gaussian distribution
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
sns.histplot(int_list2, bins=20, kde=False, stat="density", color='blue', label='Frequency')
mean, std = np.mean(int_list2), np.std(int_list2)
x = np.linspace(200, 300, 100)
p = norm.pdf(x, mean, std)
plt.plot(x, p, 'k', linewidth=2, label='Gaussian')
plt.legend()
plt.title('Frequency & Gaussian distribution')

# Frequency smoothened KDE plot
plt.subplot(1, 3, 2)
sns.histplot(int_list2, bins=20, kde=True, stat="density", color='blue', label='Frequency + KDE')
plt.legend()
plt.title('Frequency smoothened KDE plot')

# Gaussian distribution & smoothened KDE plot
plt.subplot(1, 3, 3)
sns.kdeplot(int_list2, color='red', label='KDE')
plt.plot(x, p, 'k', linewidth=2, label='Gaussian')
plt.legend()
plt.title('Gaussian distribution & smoothened KDE plot')

plt.tight_layout()
plt.show()

# %%
# (ii) Write a Python function to calculate the range of a given list of numbers.

def calculate_range(data):
    if not data:
        return None  # Return None if the list is empty
    return max(data) - min(data)

# Example usage
int_list2 = [random.randint(200, 300) for _ in range(500)]
range_value = calculate_range(int_list2)

print(f"The range of the given list is: {range_value}")
# Out:
# The range of the given list is: 100

# %%
#   (iii) Create a program to find the variance and standard deviation of a list of numbers.

import numpy as np

def calculate_variance(data):
    if not data:
        return None  # Return None if the list is empty
    mean = np.mean(data)
    variance = np.mean((data - mean) ** 2)
    return variance

def calculate_std_deviation(data):
    variance = calculate_variance(data)
    if variance is None:
        return None
    std_deviation = np.sqrt(variance)
    return std_deviation

# Example usage
int_list2 = [random.randint(200, 300) for _ in range(500)]
variance_value = calculate_variance(int_list2)
std_deviation_value = calculate_std_deviation(int_list2)

print(f"The variance of the given list is: {variance_value:.2f}")
print(f"The standard deviation of the given list is: {std_deviation_value:.2f}")
# Out:
# The variance of the given list is: 852.91
# The standard deviation of the given list is: 29.20

# %%
#   (iv) Implement a function to compute the interquartile range (IQR) of a list of values.

import numpy as np

def calculate_iqr(data):
    if not data:
        return None  # Return None if the list is empty
    q1 = np.percentile(data, 25)
    q3 = np.percentile(data, 75)
    iqr = q3 - q1
    return iqr

# Example usage
int_list2 = [random.randint(200, 300) for _ in range(500)]
iqr_value = calculate_iqr(int_list2)

print(f"The interquartile range (IQR) of the given list is: {iqr_value:.2f}")
# Out:
# The interquartile range (IQR) of the given list is: 51.00

# %%
#   (v) Build a program to calculate the coefficient of variation for a dataset.

import numpy as np

def calculate_mean(data):
    if not data:
        return None  # Return None if the list is empty
    return np.mean(data)

def calculate_std_deviation(data):
    if not data:
        return None  # Return None if the list is empty
    return np.std(data)

def calculate_coefficient_of_variation(data):
    if not data:
        return None  # Return None if the list is empty
    mean = calculate_mean(data)
    std_deviation = calculate_std_deviation(data)
    if mean == 0:
        return None  # Avoid division by zero
    cv = (std_deviation / mean) * 100  # CV expressed as a percentage
    return cv

# Example usage
int_list2 = [random.randint(200, 300) for _ in range(500)]
cv_value = calculate_coefficient_of_variation(int_list2)

print(f"The coefficient of variation (CV) of the given list is: {cv_value:.2f}%")
# Out:
# The coefficient of variation (CV) of the given list is: 11.50%

# %%
#   (vi) Write a Python function to find the mean absolute deviation (MAD) of a list of numbers.

import numpy as np

def calculate_mad(data):
    if not data:
        return None  # Return None if the list is empty
    mean = np.mean(data)
    mad = np.mean(np.abs(data - mean))
    return mad

# Example usage
int_list2 = [random.randint(200, 300) for _ in range(500)]
mad_value = calculate_mad(int_list2)

print(f"The mean absolute deviation (MAD) of the given list is: {mad_value:.2f}")
# Out:
# The mean absolute deviation (MAD) of the given list is: 24.96

# %%
#   (vii) Create a program to calculate the quartile deviation of a list of values.

import numpy as np

def calculate_quartile_deviation(data):
    if not data:
        return None  # Return None if the list is empty
    q1 = np.percentile(data, 25)
    q3 = np.percentile(data, 75)
    quartile_deviation = (q3 - q1) / 2
    return quartile_deviation

# Example usage
int_list2 = [random.randint(200, 300) for _ in range(500)]
quartile_deviation_value = calculate_quartile_deviation(int_list2)

print(f"The quartile deviation of the given list is: {quartile_deviation_value:.2f}")
# Out:
# The quartile deviation of the given list is: 26.00

# %%
#  (viii) Implement a function to find the range-based coefficient of dispersion for a dataset.

def calculate_range(data):
    if not data:
        return None  # Return None if the list is empty
    return max(data) - min(data)

def calculate_range_based_cod(data):
    if not data:
        return None  # Return None if the list is empty
    range_value = calculate_range(data)
    max_value = max(data)
    min_value = min(data)
    if (max_value + min_value) == 0:
        return None  # Avoid division by zero
    cod = range_value / (max_value + min_value)
    return cod

# Example usage
int_list2 = [random.randint(200, 300) for _ in range(500)]
cod_value = calculate_range_based_cod(int_list2)

print(f"The range-based coefficient of dispersion (COD) of the given list is: {cod_value:.4f}")
# Out:
# The range-based coefficient of dispersion (COD) of the given list is: 0.2000

# %%
# 3.  Write a Python class representing a discrete random variable with methods to calculate its expected value and variance.

class DiscreteRandomVariable:
    def __init__(self, values, probabilities):
        if len(values) != len(probabilities):
            raise ValueError("The length of values and probabilities must be the same.")
        if not np.isclose(sum(probabilities), 1):
            raise ValueError("The sum of probabilities must be 1.")
        self.values = values
        self.probabilities = probabilities

    def expected_value(self):
        return sum(value * prob for value, prob in zip(self.values, self.probabilities))

    def variance(self):
        mean = self.expected_value()
        return sum(prob * (value - mean) ** 2 for value, prob in zip(self.values, self.probabilities))

# Example usage
values = [1, 2, 3, 4, 5]
probabilities = [0.1, 0.2, 0.3, 0.2, 0.2]

drv = DiscreteRandomVariable(values, probabilities)
expected_value = drv.expected_value()
variance = drv.variance()

print(f"Expected Value: {expected_value:.2f}")
print(f"Variance: {variance:.2f}")
# Out:
# Expected Value: 3.20
# Variance: 1.56

# %%
# 4. Implement a program to simulate the rolling of a fair six-sided die and calculate the expected value and variance o6 the outcomes.

import numpy as np

class DiscreteRandomVariable:
    def __init__(self, values, probabilities):
        if len(values) != len(probabilities):
            raise ValueError("The length of values and probabilities must be the same.")
        if not np.isclose(sum(probabilities), 1):
            raise ValueError("The sum of probabilities must be 1.")
        self.values = values
        self.probabilities = probabilities

    def expected_value(self):
        return sum(value * prob for value, prob in zip(self.values, self.probabilities))

    def variance(self):
        mean = self.expected_value()
        return sum(prob * (value - mean) ** 2 for value, prob in zip(self.values, self.probabilities))

# Simulate rolling a fair six-sided die
values = [1, 2, 3, 4, 5, 6]
probabilities = [1/6] * 6  # Each side has an equal probability of 1/6

# Create an instance of DiscreteRandomVariable for the die
die = DiscreteRandomVariable(values, probabilities)

# Calculate the expected value and variance
expected_value = die.expected_value()
variance = die.variance()

print(f"Expected Value: {expected_value:.2f}")
print(f"Variance: {variance:.2f}")
# Out:
# Expected Value: 3.50
# Variance: 2.92

# %%
# 5. Create a Python function to generate random samples from a given probability distribution (e.g., binomial, Poisson) and calculate their mean and variance.

import numpy as np

def generate_random_samples(distribution, params, sample_size=1000):
    """
    Generate random samples from a given probability distribution and calculate their mean and variance.

    Args:
    distribution (str): The name of the distribution ('binomial' or 'poisson').
    params (dict): Parameters of the distribution.
    sample_size (int): The number of random samples to generate (default is 1000).

    Returns:
    tuple: Mean and variance of the generated samples.
    """
    if distribution == 'binomial':
        n = params.get('n')
        p = params.get('p')
        samples = np.random.binomial(n, p, sample_size)
    elif distribution == 'poisson':
        lam = params.get('lam')
        samples = np.random.poisson(lam, sample_size)
    else:
        raise ValueError("Unsupported distribution. Supported distributions are 'binomial' and 'poisson'.")

    mean = np.mean(samples)
    variance = np.var(samples)

    return mean, variance

# Example usage
binomial_params = {'n': 10, 'p': 0.5}
poisson_params = {'lam': 3}

binomial_mean, binomial_variance = generate_random_samples('binomial', binomial_params)
poisson_mean, poisson_variance = generate_random_samples('poisson', poisson_params)

print(f"Binomial Distribution - Mean: {binomial_mean:.2f}, Variance: {binomial_variance:.2f}")
print(f"Poisson Distribution - Mean: {poisson_mean:.2f}, Variance: {poisson_variance:.2f}")
# Out:
# Binomial Distribution - Mean: 5.01, Variance: 2.51
# Poisson Distribution - Mean: 3.09, Variance: 3.06

# %%
# 6. Write a Python script to generate random numbers from a Gaussian (normal) distribution and compute the mean, variance, and standard deviation of the samples.

import numpy as np

def generate_gaussian_samples(mean, std_dev, sample_size=1000):
    """
    Generate random samples from a Gaussian (normal) distribution and calculate their mean, variance, and standard deviation.

    Args:
    mean (float): The mean of the Gaussian distribution.
    std_dev (float): The standard deviation of the Gaussian distribution.
    sample_size (int): The number of random samples to generate (default is 1000).

    Returns:
    tuple: Mean, variance, and standard deviation of the generated samples.
    """
    samples = np.random.normal(mean, std_dev, sample_size)
    sample_mean = np.mean(samples)
    sample_variance = np.var(samples)
    sample_std_dev = np.std(samples)

    return sample_mean, sample_variance, sample_std_dev

# Example usage
mean = 0
std_dev = 1
sample_size = 1000

sample_mean, sample_variance, sample_std_dev = generate_gaussian_samples(mean, std_dev, sample_size)

print(f"Generated Gaussian Samples - Mean: {sample_mean:.2f}")
print(f"Generated Gaussian Samples - Variance: {sample_variance:.2f}")
print(f"Generated Gaussian Samples - Standard Deviation: {sample_std_dev:.2f}")
# Out:
# Generated Gaussian Samples - Mean: 0.02
# Generated Gaussian Samples - Variance: 1.00
# Generated Gaussian Samples - Standard Deviation: 1.00

# %%
# 7. Use seaborn library to load tips dataset. Find the following from the dataset for the columns total_bill and `tip`:
# (i) Write a Python function that calculates their skewness.

import seaborn as sns
import numpy as np
from scipy.stats import skew

# Load the tips dataset
tips = sns.load_dataset("tips")

def calculate_skewness(data):
    """
    Calculate the skewness of a given dataset.

    Args:
    data (list or np.ndarray): The dataset for which skewness is to be calculated.

    Returns:
    float: The skewness of the dataset.
    """
    return skew(data)

# Extract total_bill and tip columns
total_bill = tips['total_bill']
tip = tips['tip']

# Calculate skewness
total_bill_skewness = calculate_skewness(total_bill)
tip_skewness = calculate_skewness(tip)

print(f"Skewness of total_bill: {total_bill_skewness:.2f}")
print(f"Skewness of tip: {tip_skewness:.2f}")
# Out:
# Skewness of total_bill: 1.13
# Skewness of tip: 1.46

# %%
# (ii) Create a program that determines whether the columns exhibit positive skewness, negative skewness, or is approximately symmetric.

import seaborn as sns
import numpy as np
from scipy.stats import skew

def calculate_skewness(data):
    """
    Calculate the skewness of a given dataset.

    Args:
    data (list or np.ndarray): The dataset for which skewness is to be calculated.

    Returns:
    float: The skewness of the dataset.
    """
    return skew(data)

def skewness_description(skewness_value):
    """
    Determine whether the skewness value indicates positive skewness, negative skewness, or symmetry.

    Args:
    skewness_value (float): The skewness value to be evaluated.

    Returns:
    str: Description of the skewness.
    """
    if skewness_value > 0:
        return "positive skewness"
    elif skewness_value < 0:
        return "negative skewness"
    else:
        return "approximately symmetric"

# Load the tips dataset
tips = sns.load_dataset("tips")

# Extract total_bill and tip columns
total_bill = tips['total_bill']
tip = tips['tip']

# Calculate skewness
total_bill_skewness = calculate_skewness(total_bill)
tip_skewness = calculate_skewness(tip)

# Determine skewness description
total_bill_description = skewness_description(total_bill_skewness)
tip_description = skewness_description(tip_skewness)

print(f"Total_bill column exhibits {total_bill_description} (skewness: {total_bill_skewness:.2f})")
print(f"Tip column exhibits {tip_description} (skewness: {tip_skewness:.2f})")
# Out:
# Total_bill column exhibits positive skewness (skewness: 1.13)
# Tip column exhibits positive skewness (skewness: 1.46)

# %%
# (iii) Write a function that calculates the covariance between two columns.

import seaborn as sns
import numpy as np

def calculate_covariance(column1, column2):
    """
    Calculate the covariance between two columns.

    Args:
    column1 (list or np.ndarray): The first dataset column.
    column2 (list or np.ndarray): The second dataset column.

    Returns:
    float: The covariance between the two columns.
    """
    if len(column1) != len(column2):
        raise ValueError("The columns must have the same length.")
    
    mean1 = np.mean(column1)
    mean2 = np.mean(column2)
    
    covariance = np.mean((column1 - mean1) * (column2 - mean2))
    return covariance

# Load the tips dataset
tips = sns.load_dataset("tips")

# Extract total_bill and tip columns
total_bill = tips['total_bill']
tip = tips['tip']

# Calculate covariance
covariance = calculate_covariance(total_bill, tip)

print(f"Covariance between total_bill and tip: {covariance:.2f}")
# Out:
# Covariance between total_bill and tip: 8.29

# %%
# (iv) Implement a Python program that calculates the Pearson correlation coefficient between two columns.

import seaborn as sns
import numpy as np

def calculate_pearson_correlation(column1, column2):
    """
    Calculate the Pearson correlation coefficient between two columns.

    Args:
    column1 (list or np.ndarray): The first dataset column.
    column2 (list or np.ndarray): The second dataset column.

    Returns:
    float: The Pearson correlation coefficient between the two columns.
    """
    if len(column1) != len(column2):
        raise ValueError("The columns must have the same length.")
    
    mean1 = np.mean(column1)
    mean2 = np.mean(column2)
    
    covariance = np.mean((column1 - mean1) * (column2 - mean2))
    std_dev1 = np.std(column1)
    std_dev2 = np.std(column2)
    
    correlation = covariance / (std_dev1 * std_dev2)
    return correlation

# Load the tips dataset
tips = sns.load_dataset("tips")

# Extract total_bill and tip columns
total_bill = tips['total_bill']
tip = tips['tip']

# Calculate Pearson correlation coefficient
pearson_correlation = calculate_pearson_correlation(total_bill, tip)

print(f"Pearson correlation coefficient between total_bill and tip: {pearson_correlation:.2f}")
# Out:
# Pearson correlation coefficient between total_bill and tip: 0.68

# %%
# (v) Write a script to visualize the correlation between two specific columns in a Pandas DataFrame using scatter plots.

import seaborn as sns
import matplotlib.pyplot as plt

# Load the tips dataset
tips = sns.load_dataset("tips")

# Extract total_bill and tip columns
total_bill = tips['total_bill']
tip = tips['tip']

# Create a scatter plot to visualize the correlation
plt.figure(figsize=(10, 6))
sns.scatterplot(x=total_bill, y=tip)

# Add titles and labels
plt.title('Scatter Plot of Total Bill vs. Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')

# Display the plot
plt.show()

# %%
# 8. Write a Python function to calculate the probability density function (PDF) of a continuous random variable for a given normal distribution.

import numpy as np
from scipy.stats import norm

def calculate_pdf(mean, std_dev, x_values):
    """
    Calculate the probability density function (PDF) of a normal distribution for given x values.

    Args:
    mean (float): The mean of the normal distribution.
    std_dev (float): The standard deviation of the normal distribution.
    x_values (list or np.ndarray): The x values for which to calculate the PDF.

    Returns:
    np.ndarray: The PDF values corresponding to the x values.
    """
    pdf_values = norm.pdf(x_values, mean, std_dev)
    return pdf_values

# Example usage
mean = 0
std_dev = 1
x_values = np.linspace(-5, 5, 100)  # Generate 100 points between -5 and 5

pdf_values = calculate_pdf(mean, std_dev, x_values)

# Plotting the PDF
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(x_values, pdf_values, label='PDF', color='blue')
plt.title('Probability Density Function (PDF) of Normal Distribution')
plt.xlabel('X')
plt.ylabel('PDF')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 9. Create a program to calculate the cumulative distribution function (CDF) of exponential distribution.

import numpy as np
from scipy.stats import expon
import matplotlib.pyplot as plt

def calculate_cdf(scale, x_values):
    """
    Calculate the cumulative distribution function (CDF) of an exponential distribution for given x values.

    Args:
    scale (float): The scale parameter (inverse of rate parameter, lambda) of the exponential distribution.
    x_values (list or np.ndarray): The x values for which to calculate the CDF.

    Returns:
    np.ndarray: The CDF values corresponding to the x values.
    """
    cdf_values = expon.cdf(x_values, scale=scale)
    return cdf_values

# Example usage
scale = 1.0  # Corresponds to lambda = 1 (mean = 1/lambda)
x_values = np.linspace(0, 5, 100)  # Generate 100 points between 0 and 5

cdf_values = calculate_cdf(scale, x_values)

# Plotting the CDF
plt.figure(figsize=(10, 6))
plt.plot(x_values, cdf_values, label='CDF', color='blue')
plt.title('Cumulative Distribution Function (CDF) of Exponential Distribution')
plt.xlabel('X')
plt.ylabel('CDF')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 10. Write a Python function to calculate the probability mass function (PMF) of Poisson distribution.

import numpy as np
from scipy.stats import poisson
import matplotlib.pyplot as plt

def calculate_pmf(lam, k_values):
    """
    Calculate the probability mass function (PMF) of a Poisson distribution for given k values.

    Args:
    lam (float): The rate parameter (lambda) of the Poisson distribution.
    k_values (list or np.ndarray): The k values for which to calculate the PMF.

    Returns:
    np.ndarray: The PMF values corresponding to the k values.
    """
    pmf_values = poisson.pmf(k_values, lam)
    return pmf_values

# Example usage
lam = 3.0  # The rate parameter (lambda)
k_values = np.arange(0, 15)  # Generate k values from 0 to 14

pmf_values = calculate_pmf(lam, k_values)

# Plotting the PMF
plt.figure(figsize=(10, 6))
plt.stem(k_values, pmf_values, basefmt=" ", use_line_collection=True)
plt.title('Probability Mass Function (PMF) of Poisson Distribution')
plt.xlabel('k')
plt.ylabel('PMF')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_2043/3512892222.py:29: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(k_values, pmf_values, basefmt=" ", use_line_collection=True)

# %%
# 11. A company wants to test if a new website layout leads to a higher conversion rate (percentage of visitors who make a purchase). They collect data from the old and new layouts to compare.
'''
To generate the data use the following command:
```python
import numpy as np
# 50 purchases out of 1000 visitors
old_layout = <p.array([1] * 50 + [0] * 950)
# 70 purchases out of 1000 visitors  
<ew_layout = <p.array([1] * 70 + [0] * 930)
```
Apply z-test to find which layout is successful.
'''

import numpy as np
from statsmodels.stats.proportion import proportions_ztest

# Generate the data
old_layout = np.array([1] * 50 + [0] * 950)
new_layout = np.array([1] * 70 + [0] * 930)

# Calculate the number of successes and the number of trials
successes = np.array([old_layout.sum(), new_layout.sum()])
trials = np.array([old_layout.size, new_layout.size])

# Apply z-test
z_stat, p_value = proportions_ztest(successes, trials)

# Print the results
print(f"Z-statistic: {z_stat:.2f}")
print(f"P-value: {p_value:.2f}")

# Interpret the result
alpha = 0.05  # significance level
if p_value < alpha:
    print("Reject the null hypothesis: The new layout leads to a higher conversion rate.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference in conversion rates.")
# Out:
# Z-statistic: -1.88
# P-value: 0.06
# Fail to reject the null hypothesis: There is no significant difference in conversion rates.

# %%
# 12. A tutoring service claims that its program improves students' exam scores. A sample of students who participated in the program was taken, and their scores before and after the program were recorded.
'''
Use the below code to generate samples of respective arrays of marks:
```python
before_program = <p.array([75, 80, 85, 70, 90, 78, 92, 88, 82, 87])
after_program = <p.array([80, 85, 90, 80, 92, 80, 95, 90, 85, 88])
```
Use z-test to find if the claims made by tutor are true or false.
'''

import numpy as np
from scipy.stats import norm

# Generate the samples
before_program = np.array([75, 80, 85, 70, 90, 78, 92, 88, 82, 87])
after_program = np.array([80, 85, 90, 80, 92, 80, 95, 90, 85, 88])

# Calculate the differences
differences = after_program - before_program

# Calculate the mean and standard deviation of the differences
mean_diff = np.mean(differences)
std_diff = np.std(differences, ddof=1)

# Calculate the z-score
n = len(differences)
se_diff = std_diff / np.sqrt(n)
z_score = mean_diff / se_diff

# Calculate the p-value
p_value = 2 * (1 - norm.cdf(abs(z_score)))

# Print the results
print(f"Mean of differences: {mean_diff:.2f}")
print(f"Standard deviation of differences: {std_diff:.2f}")
print(f"Z-score: {z_score:.2f}")
print(f"P-value: {p_value:.2f}")

# Interpret the result
alpha = 0.05  # significance level
if p_value < alpha:
    print("Reject the null hypothesis: The tutoring program significantly improves exam scores.")
else:
    print("Fail to reject the null hypothesis: There is no significant improvement in exam scores.")
# Out:
# Mean of differences: 3.80
# Standard deviation of differences: 2.62
# Z-score: 4.59
# P-value: 0.00
# Reject the null hypothesis: The tutoring program significantly improves exam scores.

# %%
# 13. A pharmaceutical company wants to determine if a new drug is effective in reducing blood pressure. They conduct a study and record blood pressure measurements before and after administering the drug.
'''
Use the below code to generate samples of respective arrays of blood pressure:
```python
before_drug = <p.array([145, 150, 140, 135, 155, 160, 152, 148, 130, 138])
after_drug = <p.array([130, 140, 132, 128, 145, 148, 138, 136, 125, 130])
```
Impleme<t z-test to find if the drug really works or not.
'''

import numpy as np
from scipy.stats import norm

# Generate the samples
before_drug = np.array([145, 150, 140, 135, 155, 160, 152, 148, 130, 138])
after_drug = np.array([130, 140, 132, 128, 145, 148, 138, 136, 125, 130])

# Calculate the differences
differences = before_drug - after_drug

# Calculate the mean and standard deviation of the differences
mean_diff = np.mean(differences)
std_diff = np.std(differences, ddof=1)

# Calculate the z-score
n = len(differences)
se_diff = std_diff / np.sqrt(n)
z_score = mean_diff / se_diff

# Calculate the p-value
p_value = 2 * (1 - norm.cdf(abs(z_score)))

# Print the results
print(f"Mean of differences: {mean_diff:.2f}")
print(f"Standard deviation of differences: {std_diff:.2f}")
print(f"Z-score: {z_score:.2f}")
print(f"P-value: {p_value:.2f}")

# Interpret the result
alpha = 0.05  # significance level
if p_value < alpha:
    print("Reject the null hypothesis: The drug significantly reduces blood pressure.")
else:
    print("Fail to reject the null hypothesis: There is no significant reduction in blood pressure.")
# Out:
# Mean of differences: 10.10
# Standard deviation of differences: 3.18
# Z-score: 10.05
# P-value: 0.00
# Reject the null hypothesis: The drug significantly reduces blood pressure.

# %%
# 14. A customer service department claims that their average response time is less than 5 minutes. A sample of recent customer interactions was taken, and the response times were recorded.
'''
Implement the below code to generate the array of response time:
```python
response_times = 3p.array([4.3, 3.8, 5.1, 4.9, 4.7, 4.2, 5.2, 4.5, 4.6, 4.4])
```
Implement z-test to find the claims made by customer service department are true or false.
'''

import numpy as np
from scipy.stats import norm

# Generate the sample of response times
response_times = np.array([4.3, 3.8, 5.1, 4.9, 4.7, 4.2, 5.2, 4.5, 4.6, 4.4])

# Hypothesized population mean (mu)
mu = 5.0

# Calculate the sample mean and standard deviation
sample_mean = np.mean(response_times)
sample_std = np.std(response_times, ddof=1)

# Calculate the sample size
n = len(response_times)

# Calculate the standard error of the mean
se = sample_std / np.sqrt(n)

# Calculate the z-score
z_score = (sample_mean - mu) / se

# Calculate the p-value for one-tailed test
p_value = norm.cdf(z_score)

# Print the results
print(f"Sample mean: {sample_mean:.2f}")
print(f"Sample standard deviation: {sample_std:.2f}")
print(f"Z-score: {z_score:.2f}")
print(f"P-value: {p_value:.4f}")

# Interpret the result
alpha = 0.05  # significance level
if p_value < alpha:
    print("Reject the null hypothesis: The customer service department's claim is true. The average response time is less than 5 minutes.")
else:
    print("Fail to reject the null hypothesis: There is no significant evidence that the average response time is less than 5 minutes.")
# Out:
# Sample mean: 4.57
# Sample standard deviation: 0.43
# Z-score: -3.18
# P-value: 0.0007
# Reject the null hypothesis: The customer service department's claim is true. The average response time is less than 5 minutes.

# %%
# 15. A company is testing two different website layouts to see which one leads to higher click-through rates. Write a Python function to perform an A/B test analysis, including calculating the t-statistic, degrees of freedom, and p-value.
'''
Use the following data:
```python
layout_a_clicks = [28, 32, 33, 29, 31, 34, 30, 35, 36, 37]
layout_b_clicks = [40, 41, 38, 42, 39, 44, 43, 41, 45, 47]
'''

import numpy as np
from scipy.stats import t

def ab_test_analysis(layout_a_clicks, layout_b_clicks):
    # Convert to numpy arrays
    layout_a = np.array(layout_a_clicks)
    layout_b = np.array(layout_b_clicks)
    
    # Calculate sample means and standard deviations
    mean_a = np.mean(layout_a)
    mean_b = np.mean(layout_b)
    std_a = np.std(layout_a, ddof=1)
    std_b = np.std(layout_b, ddof=1)
    
    # Sample sizes
    n_a = len(layout_a)
    n_b = len(layout_b)
    
    # Calculate pooled standard deviation
    pooled_std = np.sqrt(((std_a ** 2) / n_a) + ((std_b ** 2) / n_b))
    
    # Calculate the t-statistic
    t_stat = (mean_a - mean_b) / pooled_std
    
    # Calculate degrees of freedom
    df = (((std_a ** 2) / n_a + (std_b ** 2) / n_b) ** 2) / \
         (((((std_a ** 2) / n_a) ** 2) / (n_a - 1)) + ((((std_b ** 2) / n_b) ** 2) / (n_b - 1)))
    
    # Calculate the p-value (two-tailed test)
    p_value = 2 * (1 - t.cdf(abs(t_stat), df))
    
    # Print the results
    print(f"Mean of Layout A: {mean_a:.2f}")
    print(f"Mean of Layout B: {mean_b:.2f}")
    print(f"Standard Deviation of Layout A: {std_a:.2f}")
    print(f"Standard Deviation of Layout B: {std_b:.2f}")
    print(f"T-statistic: {t_stat:.2f}")
    print(f"Degrees of Freedom: {df:.2f}")
    print(f"P-value: {p_value:.4f}")
    
    # Interpret the result
    alpha = 0.05  # significance level
    if p_value < alpha:
        print("Reject the null hypothesis: There is a significant difference in click-through rates between the two layouts.")
    else:
        print("Fail to reject the null hypothesis: There is no significant difference in click-through rates between the two layouts.")

# Example usage
layout_a_clicks = [28, 32, 33, 29, 31, 34, 30, 35, 36, 37]
layout_b_clicks = [40, 41, 38, 42, 39, 44, 43, 41, 45, 47]

ab_test_analysis(layout_a_clicks, layout_b_clicks)
# Out:
# Mean of Layout A: 32.50
# Mean of Layout B: 42.00
# Standard Deviation of Layout A: 3.03
# Standard Deviation of Layout B: 2.79
# T-statistic: -7.30
# Degrees of Freedom: 17.88
# P-value: 0.0000
# Reject the null hypothesis: There is a significant difference in click-through rates between the two layouts.

# %%
# 16. A pharmaceutical company wants to determine if a new drug is more effective than an existing drug in reducing cholesterol levels. Create a program to analyze the clinical trial data and calculate the t-statistic and p-value for the treatment effect.
'''
Use the following data of cholestrol level:
```python
existing_drug_levels = [180, 182, 175, 185, 178, 176, 172, 184, 179, 183]
new_drug_levels = [170, 172, 165, 168, 175, 173, 170, 178, 172, 176]
```
'''

import numpy as np
from scipy.stats import t

def treatment_effect_analysis(existing_drug_levels, new_drug_levels):
    # Convert to numpy arrays
    existing_drug = np.array(existing_drug_levels)
    new_drug = np.array(new_drug_levels)
    
    # Calculate sample means and standard deviations
    mean_existing = np.mean(existing_drug)
    mean_new = np.mean(new_drug)
    std_existing = np.std(existing_drug, ddof=1)
    std_new = np.std(new_drug, ddof=1)
    
    # Sample sizes
    n_existing = len(existing_drug)
    n_new = len(new_drug)
    
    # Calculate pooled standard deviation
    pooled_std = np.sqrt(((std_existing ** 2) / n_existing) + ((std_new ** 2) / n_new))
    
    # Calculate the t-statistic
    t_stat = (mean_existing - mean_new) / pooled_std
    
    # Calculate degrees of freedom
    df = (((std_existing ** 2) / n_existing + (std_new ** 2) / n_new) ** 2) / \
         (((((std_existing ** 2) / n_existing) ** 2) / (n_existing - 1)) + ((((std_new ** 2) / n_new) ** 2) / (n_new - 1)))
    
    # Calculate the p-value (two-tailed test)
    p_value = 2 * (1 - t.cdf(abs(t_stat), df))
    
    # Print the results
    print(f"Mean of Existing Drug: {mean_existing:.2f}")
    print(f"Mean of New Drug: {mean_new:.2f}")
    print(f"Standard Deviation of Existing Drug: {std_existing:.2f}")
    print(f"Standard Deviation of New Drug: {std_new:.2f}")
    print(f"T-statistic: {t_stat:.2f}")
    print(f"Degrees of Freedom: {df:.2f}")
    print(f"P-value: {p_value:.4f}")
    
    # Interpret the result
    alpha = 0.05  # significance level
    if p_value < alpha:
        print("Reject the null hypothesis: The new drug significantly reduces cholesterol levels more than the existing drug.")
    else:
        print("Fail to reject the null hypothesis: There is no significant difference in cholesterol reduction between the new and existing drugs.")

# Example usage
existing_drug_levels = [180, 182, 175, 185, 178, 176, 172, 184, 179, 183]
new_drug_levels = [170, 172, 165, 168, 175, 173, 170, 178, 172, 176]

treatment_effect_analysis(existing_drug_levels, new_drug_levels)
# Out:
# Mean of Existing Drug: 179.40
# Mean of New Drug: 171.90
# Standard Deviation of Existing Drug: 4.22
# Standard Deviation of New Drug: 3.87
# T-statistic: 4.14
# Degrees of Freedom: 17.87
# P-value: 0.0006
# Reject the null hypothesis: The new drug significantly reduces cholesterol levels more than the existing drug.

# %%
# 17. A school district introduces an educational intervention program to improve math scores. Write a Python function to analyze pre- and post-intervention test scores, calculating the t-statistic and p-value to determine if the intervention had a significant impact.
'''
Use the following data of test score:
```python
pre_intervention_scores = [80, 85, 90, 75, 88, 82, 92, 78, 85, 87]
post_intervention_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]
```
'''

import numpy as np
from scipy.stats import t

def intervention_impact_analysis(pre_scores, post_scores):
    # Convert to numpy arrays
    pre = np.array(pre_scores)
    post = np.array(post_scores)
    
    # Calculate the differences
    differences = post - pre
    
    # Calculate the sample mean and standard deviation of the differences
    mean_diff = np.mean(differences)
    std_diff = np.std(differences, ddof=1)
    
    # Calculate the sample size
    n = len(differences)
    
    # Calculate the standard error of the mean difference
    se_diff = std_diff / np.sqrt(n)
    
    # Calculate the t-statistic
    t_stat = mean_diff / se_diff
    
    # Calculate the degrees of freedom
    df = n - 1
    
    # Calculate the p-value for a two-tailed test
    p_value = 2 * (1 - t.cdf(abs(t_stat), df))
    
    # Print the results
    print(f"Mean difference: {mean_diff:.2f}")
    print(f"Standard deviation of differences: {std_diff:.2f}")
    print(f"T-statistic: {t_stat:.2f}")
    print(f"Degrees of Freedom: {df}")
    print(f"P-value: {p_value:.4f}")
    
    # Interpret the result
    alpha = 0.05  # significance level
    if p_value < alpha:
        print("Reject the null hypothesis: The intervention had a significant impact on math scores.")
    else:
        print("Fail to reject the null hypothesis: There is no significant impact of the intervention on math scores.")

# Example usage
pre_intervention_scores = [80, 85, 90, 75, 88, 82, 92, 78, 85, 87]
post_intervention_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]

intervention_impact_analysis(pre_intervention_scores, post_intervention_scores)
# Out:
# Mean difference: 7.70
# Standard deviation of differences: 5.50
# T-statistic: 4.43
# Degrees of Freedom: 9
# P-value: 0.0017
# Reject the null hypothesis: The intervention had a significant impact on math scores.

# %%
# 18. An HR department wants to investigate if there's a gender-based salary gap within the company. Develop a program to analyze salary data, calculate the t-statistic, and determine if there's a statistically significant difference between the average salaries of male and female employees.
'''
Use the below code to generate synthetic data:
```python
# Generate synthetic salary data for male and female employees
np.random.seed(0)  # For reproducibility
male_salaries = np.random.normal(loc=50000, scale=10000, size=20)
female_salaries = np.random.normal(loc=55000, scale=9000, size=20)
```
'''

import numpy as np
from scipy.stats import t

def gender_salary_gap_analysis(male_salaries, female_salaries):
    # Convert to numpy arrays
    male = np.array(male_salaries)
    female = np.array(female_salaries)
    
    # Calculate sample means and standard deviations
    mean_male = np.mean(male)
    mean_female = np.mean(female)
    std_male = np.std(male, ddof=1)
    std_female = np.std(female, ddof=1)
    
    # Sample sizes
    n_male = len(male)
    n_female = len(female)
    
    # Calculate pooled standard deviation
    pooled_std = np.sqrt(((std_male ** 2) / n_male) + ((std_female ** 2) / n_female))
    
    # Calculate the t-statistic
    t_stat = (mean_male - mean_female) / pooled_std
    
    # Calculate degrees of freedom
    df = (((std_male ** 2) / n_male + (std_female ** 2) / n_female) ** 2) / \
         (((((std_male ** 2) / n_male) ** 2) / (n_male - 1)) + ((((std_female ** 2) / n_female) ** 2) / (n_female - 1)))
    
    # Calculate the p-value (two-tailed test)
    p_value = 2 * (1 - t.cdf(abs(t_stat), df))
    
    # Print the results
    print(f"Mean Salary of Male Employees: ${mean_male:.2f}")
    print(f"Mean Salary of Female Employees: ${mean_female:.2f}")
    print(f"Standard Deviation of Male Salaries: ${std_male:.2f}")
    print(f"Standard Deviation of Female Salaries: ${std_female:.2f}")
    print(f"T-statistic: {t_stat:.2f}")
    print(f"Degrees of Freedom: {df:.2f}")
    print(f"P-value: {p_value:.4f}")
    
    # Interpret the result
    alpha = 0.05  # significance level
    if p_value < alpha:
        print("Reject the null hypothesis: There is a significant difference in average salaries between male and female employees.")
    else:
        print("Fail to reject the null hypothesis: There is no significant difference in average salaries between male and female employees.")

# Generate synthetic salary data for male and female employees
np.random.seed(0)  # For reproducibility
male_salaries = np.random.normal(loc=50000, scale=10000, size=20)
female_salaries = np.random.normal(loc=55000, scale=9000, size=20)

# Perform the analysis
gender_salary_gap_analysis(male_salaries, female_salaries)
# Out:
# Mean Salary of Male Employees: $55693.35
# Mean Salary of Female Employees: $55501.75
# Standard Deviation of Male Salaries: $8722.69
# Standard Deviation of Female Salaries: $10968.10
# T-statistic: 0.06
# Degrees of Freedom: 36.17
# P-value: 0.9516
# Fail to reject the null hypothesis: There is no significant difference in average salaries between male and female employees.

# %%
# 19. A manufacturer produces two different versions of a product and wants to compare their quality scores. Create a Python function to analyze quality assessment data, calculate the t-statistic, and decide whether there's a significant difference in quality between the two versions.
'''
Use the following data:
```python
version1_scores = [85, 88, 82, 89, 87, 84, 90, 88, 85, 86, 91, 83, 87, 84, 89, 86, 84, 88, 85, 86, 89, 90, 87, 88, 85]
version2_scores = [80, 78, 83, 81, 79, 82, 76, 80, 78, 81, 77, 82, 80, 79, 82, 79, 80, 81, 79, 82, 79, 78, 80, 81, 82]
```
'''

import numpy as np
from scipy.stats import t

def quality_comparison(version1_scores, version2_scores):
    # Convert to numpy arrays
    version1 = np.array(version1_scores)
    version2 = np.array(version2_scores)
    
    # Calculate sample means and standard deviations
    mean_v1 = np.mean(version1)
    mean_v2 = np.mean(version2)
    std_v1 = np.std(version1, ddof=1)
    std_v2 = np.std(version2, ddof=1)
    
    # Sample sizes
    n_v1 = len(version1)
    n_v2 = len(version2)
    
    # Calculate pooled standard deviation
    pooled_std = np.sqrt(((std_v1 ** 2) / n_v1) + ((std_v2 ** 2) / n_v2))
    
    # Calculate the t-statistic
    t_stat = (mean_v1 - mean_v2) / pooled_std
    
    # Calculate degrees of freedom
    df = (((std_v1 ** 2) / n_v1 + (std_v2 ** 2) / n_v2) ** 2) / \
         (((((std_v1 ** 2) / n_v1) ** 2) / (n_v1 - 1)) + ((((std_v2 ** 2) / n_v2) ** 2) / (n_v2 - 1)))
    
    # Calculate the p-value (two-tailed test)
    p_value = 2 * (1 - t.cdf(abs(t_stat), df))
    
    # Print the results
    print(f"Mean Quality Score of Version 1: {mean_v1:.2f}")
    print(f"Mean Quality Score of Version 2: {mean_v2:.2f}")
    print(f"Standard Deviation of Version 1 Scores: {std_v1:.2f}")
    print(f"Standard Deviation of Version 2 Scores: {std_v2:.2f}")
    print(f"T-statistic: {t_stat:.2f}")
    print(f"Degrees of Freedom: {df:.2f}")
    print(f"P-value: {p_value:.4f}")
    
    # Interpret the result
    alpha = 0.05  # significance level
    if p_value < alpha:
        print("Reject the null hypothesis: There is a significant difference in quality between the two versions.")
    else:
        print("Fail to reject the null hypothesis: There is no significant difference in quality between the two versions.")

# Example usage
version1_scores = [85, 88, 82, 89, 87, 84, 90, 88, 85, 86, 91, 83, 87, 84, 89, 86, 84, 88, 85, 86, 89, 90, 87, 88, 85]
version2_scores = [80, 78, 83, 81, 79, 82, 76, 80, 78, 81, 77, 82, 80, 79, 82, 79, 80, 81, 79, 82, 79, 78, 80, 81, 82]

quality_comparison(version1_scores, version2_scores)
# Out:
# Mean Quality Score of Version 1: 86.64
# Mean Quality Score of Version 2: 79.96
# Standard Deviation of Version 1 Scores: 2.36
# Standard Deviation of Version 2 Scores: 1.77
# T-statistic: 11.33
# Degrees of Freedom: 44.47
# P-value: 0.0000
# Reject the null hypothesis: There is a significant difference in quality between the two versions.

# %%
# 20. A restaurant chain collects customer satisfaction scores for two different branches. Write a program to analyze the scores, calculate the t-statistic, and determine if there's a statistically significant difference in customer satisfaction between the branches.
'''
Use the below data of scores:
```python
branch_a_scores = [4, 5, 3, 4, 5, 4, 5, 3, 4, 4, 5, 4, 4, 3, 4, 5, 5, 4, 3, 4, 5, 4, 3, 5, 4, 4, 5, 3, 4, 5, 4]
branch_b_scores = [3, 4, 2, 3, 4, 3, 4, 2, 3, 3, 4, 3, 3, 2, 3, 4, 4, 3, 2, 3, 4, 3, 2, 4, 3, 3, 4, 2, 3, 4, 3]
'''

import numpy as np
from scipy.stats import t

def customer_satisfaction_analysis(branch_a_scores, branch_b_scores):
    # Convert to numpy arrays
    branch_a = np.array(branch_a_scores)
    branch_b = np.array(branch_b_scores)
    
    # Calculate sample means and standard deviations
    mean_a = np.mean(branch_a)
    mean_b = np.mean(branch_b)
    std_a = np.std(branch_a, ddof=1)
    std_b = np.std(branch_b, ddof=1)
    
    # Sample sizes
    n_a = len(branch_a)
    n_b = len(branch_b)
    
    # Calculate pooled standard deviation
    pooled_std = np.sqrt(((std_a ** 2) / n_a) + ((std_b ** 2) / n_b))
    
    # Calculate the t-statistic
    t_stat = (mean_a - mean_b) / pooled_std
    
    # Calculate degrees of freedom
    df = (((std_a ** 2) / n_a + (std_b ** 2) / n_b) ** 2) / \
         (((((std_a ** 2) / n_a) ** 2) / (n_a - 1)) + ((((std_b ** 2) / n_b) ** 2) / (n_b - 1)))
    
    # Calculate the p-value (two-tailed test)
    p_value = 2 * (1 - t.cdf(abs(t_stat), df))
    
    # Print the results
    print(f"Mean Customer Satisfaction Score of Branch A: {mean_a:.2f}")
    print(f"Mean Customer Satisfaction Score of Branch B: {mean_b:.2f}")
    print(f"Standard Deviation of Branch A Scores: {std_a:.2f}")
    print(f"Standard Deviation of Branch B Scores: {std_b:.2f}")
    print(f"T-statistic: {t_stat:.2f}")
    print(f"Degrees of Freedom: {df:.2f}")
    print(f"P-value: {p_value:.4f}")
    
    # Interpret the result
    alpha = 0.05  # significance level
    if p_value < alpha:
        print("Reject the null hypothesis: There is a significant difference in customer satisfaction between the two branches.")
    else:
        print("Fail to reject the null hypothesis: There is no significant difference in customer satisfaction between the two branches.")

# Example usage
branch_a_scores = [4, 5, 3, 4, 5, 4, 5, 3, 4, 4, 5, 4, 4, 3, 4, 5, 5, 4, 3, 4, 5, 4, 3, 5, 4, 4, 5, 3, 4, 5, 4]
branch_b_scores = [3, 4, 2, 3, 4, 3, 4, 2, 3, 3, 4, 3, 3, 2, 3, 4, 4, 3, 2, 3, 4, 3, 2, 4, 3, 3, 4, 2, 3, 4, 3]

customer_satisfaction_analysis(branch_a_scores, branch_b_scores)
# Out:
# Mean Customer Satisfaction Score of Branch A: 4.13
# Mean Customer Satisfaction Score of Branch B: 3.13
# Standard Deviation of Branch A Scores: 0.72
# Standard Deviation of Branch B Scores: 0.72
# T-statistic: 5.48
# Degrees of Freedom: 60.00
# P-value: 0.0000
# Reject the null hypothesis: There is a significant difference in customer satisfaction between the two branches.

# %%
# 21. A political analyst wants to determine if there is a significant association between age groups and voter preferences FCandidate A or Candidate B). They collect data from a sample of 500 voters and classify them into different age groups and candidate preferences. Perform a Chi-Square test to determine if there is a significant association between age groups and voter preferences.
'''
Use the below code to generate data:
```python
np.random.seed(0)
age_groups = np.random.choice([ 18 30 , 31 50 , 51+', 51+'], size=30)
voter_preferences = np.random.choice(['Candidate A', 'Candidate B'], size=30)
'''

import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Generate data
np.random.seed(0)
age_groups = np.random.choice(['18-30', '31-50', '51+'], size=500)
voter_preferences = np.random.choice(['Candidate A', 'Candidate B'], size=500)

# Create a DataFrame
data = pd.DataFrame({'Age Group': age_groups, 'Voter Preference': voter_preferences})

# Create a contingency table
contingency_table = pd.crosstab(data['Age Group'], data['Voter Preference'])

# Perform Chi-Square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Print the results
print("Contingency Table:")
print(contingency_table)
print("\nChi-Square Statistic:", chi2)
print("Degrees of Freedom:", dof)
print("P-value:", p)
print("\nExpected Frequencies Table:")
print(expected)

# Interpret the result
alpha = 0.05  # significance level
if p < alpha:
    print("\nReject the null hypothesis: There is a significant association between age groups and voter preferences.")
else:
    print("\nFail to reject the null hypothesis: There is no significant association between age groups and voter preferences.")

# Example usage
age_groups = np.random.choice(['18-30', '31-50', '51+'], size=30)
voter_preferences = np.random.choice(['Candidate A', 'Candidate B'], size=30)
# Out:
# Contingency Table:
# Voter Preference  Candidate A  Candidate B
# Age Group
# 18-30                      95           87
# 31-50                      87           82
# 51+                        84           65
#
# Chi-Square Statistic: 0.8779923945254768
# Degrees of Freedom: 2
# P-value: 0.6446832311860852
#
# Expected Frequencies Table:
# [[96.824 85.176]
#  [89.908 79.092]
#  [79.268 69.732]]
#
# Fail to reject the null hypothesis: There is no significant association between age groups and voter preferences.

# %%
# 22. A company conducted a customer satisfaction survey to determine if there is a significant relationship between product satisfaction levels (Satisfied, Neutral, Dissatisfied) and the region where customers are located (East, West, North, South). The survey data is summarized in a contingency table. Conduct a ChiSquare test to determine if there is a significant relationship between product satisfaction levels and customer regions.
'''
Sample data:
```python
#Sample data: Product satisfaction levels (rows) vs. Customer regions (columns)
data = np.array([[50, 30, 40, 20], [30, 40, 30, 50], [20, 30, 40, 30]])
```
'''

import numpy as np
from scipy.stats import chi2_contingency

# Sample data: Product satisfaction levels (rows) vs. Customer regions (columns)
data = np.array([[50, 30, 40, 20], [30, 40, 30, 50], [20, 30, 40, 30]])

# Perform Chi-Square test
chi2, p, dof, expected = chi2_contingency(data)

# Print the results
print("Contingency Table:")
print(data)
print("\nChi-Square Statistic:", chi2)
print("Degrees of Freedom:", dof)
print("P-value:", p)
print("\nExpected Frequencies Table:")
print(expected)

# Interpret the result
alpha = 0.05  # significance level
if p < alpha:
    print("\nReject the null hypothesis: There is a significant relationship between product satisfaction levels and customer regions.")
else:
    print("\nFail to reject the null hypothesis: There is no significant relationship between product satisfaction levels and customer regions.")
# Out:
# Contingency Table:
# [[50 30 40 20]
#  [30 40 30 50]
#  [20 30 40 30]]
#
# Chi-Square Statistic: 27.777056277056275
# Degrees of Freedom: 6
# P-value: 0.00010349448486004387
#
# Expected Frequencies Table:
# [[34.14634146 34.14634146 37.56097561 34.14634146]
#  [36.58536585 36.58536585 40.24390244 36.58536585]
#  [29.26829268 29.26829268 32.19512195 29.26829268]]
#
# Reject the null hypothesis: There is a significant relationship between product satisfaction levels and customer regions.

# %%
#  23. A company implemented an employee training program to improve job performance (Effective, Neutral, Ineffective). After the training, they collected data from a sample of employees and classified them based on their job performance before and after the training. Perform a Chi-Square test to determine if there is a significant difference between job performance levels before and after the training.
'''
Sample data:
```python
# Sample data: Job performance levels before (rows) and after (columns) training
data = np.array([[50, 30, 20], [30, 40, 30], [20, 30, 40]])
```
'''

import numpy as np
from scipy.stats import chi2_contingency

# Sample data: Job performance levels before (rows) and after (columns) training
data = np.array([[50, 30, 20], [30, 40, 30], [20, 30, 40]])

# Perform Chi-Square test
chi2, p, dof, expected = chi2_contingency(data)

# Print the results
print("Contingency Table:")
print(data)
print("\nChi-Square Statistic:", chi2)
print("Degrees of Freedom:", dof)
print("P-value:", p)
print("\nExpected Frequencies Table:")
print(expected)

# Interpret the result
alpha = 0.05  # significance level
if p < alpha:
    print("\nReject the null hypothesis: There is a significant difference between job performance levels before and after the training.")
else:
    print("\nFail to reject the null hypothesis: There is no significant difference between job performance levels before and after the training.")
# Out:
# Contingency Table:
# [[50 30 20]
#  [30 40 30]
#  [20 30 40]]
#
# Chi-Square Statistic: 22.161728395061726
# Degrees of Freedom: 4
# P-value: 0.00018609719479882557
#
# Expected Frequencies Table:
# [[34.48275862 34.48275862 31.03448276]
#  [34.48275862 34.48275862 31.03448276]
#  [31.03448276 31.03448276 27.93103448]]
#
# Reject the null hypothesis: There is a significant difference between job performance levels before and after the training.

# %%
# 24. A company produces three different versions of a product: Standard, Premium, and Deluxe. The company wants to determine if there is a significant difference in customer satisfaction scores among the three product versions. They conducted a survey and collected customer satisfaction scores for each version from a random sample of customers. Perform an ANOVA test to determine if there is a significant difference in customer satisfaction scores.
'''
Use the following data:
```python
# Sample data: Customer satisfaction scores for each product version
standard_scores = [80, 85, 90, 78, 88, 82, 92, 78, 85, 87]
premium_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]
deluxe_scores = [95, 98, 92, 97, 96, 94, 98, 97, 92, 99]
```
'''

import numpy as np
import scipy.stats as stats

# Sample data: Customer satisfaction scores for each product version
standard_scores = [80, 85, 90, 78, 88, 82, 92, 78, 85, 87]
premium_scores = [90, 92, 88, 92, 95, 91, 96, 93, 89, 93]
deluxe_scores = [95, 98, 92, 97, 96, 94, 98, 97, 92, 99]

# Perform one-way ANOVA
f_statistic, p_value = stats.f_oneway(standard_scores, premium_scores, deluxe_scores)

# Print the results
print("ANOVA Results:")
print("F-Statistic:", f_statistic)
print("P-value:", p_value)

# Interpret the result
alpha = 0.05  # significance level
if p_value < alpha:
    print("\nReject the null hypothesis: There is a significant difference in customer satisfaction scores among the three product versions.")
else:
    print("\nFail to reject the null hypothesis: There is no significant difference in customer satisfaction scores among the three product versions.")
# Out:
# ANOVA Results:
# F-Statistic: 27.03556231003039
# P-value: 3.5786328857349003e-07
#
# Reject the null hypothesis: There is a significant difference in customer satisfaction scores among the three product versions.

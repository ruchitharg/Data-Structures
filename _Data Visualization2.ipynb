# %%
# PLOTLY ASSIGNMENT:

# 1. Using the given dataset, to generate a 3D scatter plot to visualize the distribution of data points in a threedimensional space.
# np.random.seed(30)
# data = {
#    'X': np.random.uniform(-10, 10, 300),
#    'Y': np.random.uniform(-10, 10, 300),
#    'Z': np.random.uniform(-10, 10, 300)
# }
# df = pd.DataFrame(data)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generate dataset
np.random.seed(30)
data = {
    'X': np.random.uniform(-10, 10, 300),
    'Y': np.random.uniform(-10, 10, 300),
    'Z': np.random.uniform(-10, 10, 300)
}
df = pd.DataFrame(data)

# Create 3D scatter plot
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(df['X'], df['Y'], df['Z'], c=df['Z'], cmap='viridis')

# Add color bar which maps values to colors
cbar = plt.colorbar(sc)
cbar.set_label('Z value')

# Set labels
ax.set_title('3D Scatter Plot of Dataset')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %%
# 2. Using the Student Grades, create a violin plot to display the distribution of scores across different grade categories.
'''
np.random.seed(15)
data = {
    'Grade': np.random.choice(['A', 'B', 'C', 'D', 'F'], 200),
    'Score': np.random.randint(50, 100, 200)
}
df = pd.DataFrame(data
1. Using the sales data, generate a heatmap to visualize the variation in sales across different months and days.

np.random.seed(20)
data = {
    'Month': np.random.choice(['Jan', 'Feb', 'Mar', 'Apr', 'May'], 100),
    'Day': np.random.choice(range(1, 31), 100),
    'Sales': np.random.randint(1000, 5000, 100)
}
df = pd.DataFrame(data)
'''

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Generate dataset for student grades
np.random.seed(15)
data_grades = {
    'Grade': np.random.choice(['A', 'B', 'C', 'D', 'F'], 200),
    'Score': np.random.randint(50, 100, 200)
}
df_grades = pd.DataFrame(data_grades)

# Create violin plot
plt.figure(figsize=(10, 6))
sns.violinplot(x='Grade', y='Score', data=df_grades, palette='muted')
plt.title('Distribution of Scores Across Different Grade Categories')
plt.xlabel('Grade')
plt.ylabel('Score')
plt.grid(True)
plt.show()

# %%
# Generate dataset for sales data
np.random.seed(20)
data_sales = {
    'Month': np.random.choice(['Jan', 'Feb', 'Mar', 'Apr', 'May'], 100),
    'Day': np.random.choice(range(1, 31), 100),
    'Sales': np.random.randint(1000, 5000, 100)
}
df_sales = pd.DataFrame(data_sales)

# Pivot the data to create a matrix format suitable for heatmap
pivot_table = df_sales.pivot_table(index='Day', columns='Month', values='Sales', aggfunc='sum', fill_value=0)

# Create heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, annot=True, fmt='d', cmap='YlGnBu', linewidths=0.5)
plt.title('Heatmap of Sales Data Across Different Months and Days')
plt.xlabel('Month')
plt.ylabel('Day')
plt.show()

# %%
# 3. Using the sales data, generate a heatmap to visualize the variation in sales across different months and days.
'''
np.random.seed(20)
data = {
    'Month': np.random.choice(['Jan', 'Feb', 'Mar', 'Apr', 'May'], 100),
    'Day': np.random.choice(range(1, 31), 100),
    'Sales': np.random.randint(1000, 5000, 100)
}
df = pd.DataFrame(data)
'''

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Generate dataset for sales data
np.random.seed(20)
data = {
    'Month': np.random.choice(['Jan', 'Feb', 'Mar', 'Apr', 'May'], 100),
    'Day': np.random.choice(range(1, 31), 100),
    'Sales': np.random.randint(1000, 5000, 100)
}
df = pd.DataFrame(data)

# Pivot the data to create a matrix format suitable for heatmap
pivot_table = df.pivot_table(index='Day', columns='Month', values='Sales', aggfunc='sum', fill_value=0)

# Create heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, annot=True, fmt='d', cmap='YlGnBu', linewidths=0.5)
plt.title('Heatmap of Sales Data Across Different Months and Days')
plt.xlabel('Month')
plt.ylabel('Day')
plt.show()

# %%
# 4. Using the given x and y data, generate a 3D surface plot to visualize the function, z = sin(sqrt(x**2 + y**2))
'''
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 + y**2))
data = {
    'X': x.flatten(),
    'Y': y.flatten(),
    'Z': z.flatten()
}
df = pd.DataFrame(data)
'''

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generate dataset
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 + y**2))

# Flatten the data and create a DataFrame
data = {
    'X': x.flatten(),
    'Y': y.flatten(),
    'Z': z.flatten()
}
df = pd.DataFrame(data)

# Create 3D surface plot
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_surface(x, y, z, cmap='viridis')

# Set labels
ax.set_title('3D Surface Plot of z = sin(sqrt(x^2 + y^2))')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %%
# 5. Using the given dataset, create a bubble chart to represent each country's population (y-axis), GDP (xaxis), and bubble size proportional to the population.
'''
np.random.seed(25)
data = {
    'Country': ['USA', 'Canada', 'UK','Germany', 'France'],
    'Population':
np.random.randint(100, 1000, 5),
    'GDP': np.random.randint(500, 2000, 5)
}
df = pd.DataFrame(data)
'''

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Generate dataset
np.random.seed(25)
data = {
    'Country': ['USA', 'Canada', 'UK', 'Germany', 'France'],
    'Population': np.random.randint(100, 1000, 5),
    'GDP': np.random.randint(500, 2000, 5)
}
df = pd.DataFrame(data)

# Create bubble chart
plt.figure(figsize=(10, 6))
plt.scatter(df['GDP'], df['Population'], s=df['Population'] * 10, alpha=0.5, edgecolors='w', linewidth=2)

# Annotate each point with the country name
for i, row in df.iterrows():
    plt.text(row['GDP'], row['Population'], row['Country'], fontsize=12, ha='right')

plt.title('Bubble Chart of Country Population vs GDP')
plt.xlabel('GDP')
plt.ylabel('Population')
plt.grid(True)
plt.show()

# %%
# BOKEH ASSIGNMENT:

# 1.Create a Bokeh plot displaying a sine wave. Set x-values from 0 to 10 and y-values as the sine of x.

import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Enable the output to show in the notebook (if using a notebook)
output_notebook()

# Generate x and y values
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a Bokeh plot
p = figure(title="Sine Wave", x_axis_label='x', y_axis_label='y', width=800, height=400)

# Add a line renderer with legend and line thickness
p.line(x, y, legend_label="sin(x)", line_width=2)

# Show the plot
show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1001">Loading BokehJS ...</span>
#     </div>
#   <div id="474136f0-6f6b-4283-bb22-9eb607a568da" data-root-id="p1002" style="display: contents;"></div>

# %%
# 2.Create a Bokeh scatter plot using randomly generated x and y values. Use different sizes and colors for the markers based on the 'sizes' and 'colors' columns.

import numpy as np
import pandas as pd
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource

# Enable the output to show in the notebook (if using a notebook)
output_notebook()

# Generate random data
np.random.seed(42)
data = {
    'x': np.random.rand(100) * 100,
    'y': np.random.rand(100) * 100,
    'sizes': np.random.randint(10, 40, 100),
    'colors': np.random.choice(['#ff0000', '#00ff00', '#0000ff', '#ff00ff', '#00ffff'], 100)
}
df = pd.DataFrame(data)

# Create a ColumnDataSource from the dataframe
source = ColumnDataSource(df)

# Create a Bokeh plot
p = figure(title="Scatter Plot with Varying Sizes and Colors", x_axis_label='X', y_axis_label='Y', width=800, height=400)

# Add scatter renderer
p.scatter('x', 'y', size='sizes', color='colors', alpha=0.6, source=source)

# Show the plot
show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1156">Loading BokehJS ...</span>
#     </div>
#   <div id="65eec020-a238-443a-9c30-44075e18a3f0" data-root-id="p1160" style="display: contents;"></div>

# %%
# 3. Generate a Bokeh bar chart representing the counts of different fruits using the following dataset.
'''
fruits = ['Apples', 'Oranges', 'Bananas', 'Pears']
counts = [20, 25, 30, 35]
'''

from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.transform import factor_cmap
from bokeh.models import ColumnDataSource

# Enable the output to show in the notebook (if using a notebook)
output_notebook()

# Define the dataset
fruits = ['Apples', 'Oranges', 'Bananas', 'Pears']
counts = [20, 25, 30, 35]

# Create a ColumnDataSource from the dataset
source = ColumnDataSource(data=dict(fruits=fruits, counts=counts))

# Define the colors for each fruit
colors = ["#c9d9d3", "#718dbf", "#e84d60", "#ddb7b1"]

# Create a Bokeh plot
p = figure(x_range=fruits, height=400, width=800, title="Fruit Counts",
           toolbar_location=None, tools="")

# Add bar renderer
p.vbar(x='fruits', top='counts', width=0.9, source=source, legend_field="fruits",
       line_color='white', fill_color=factor_cmap('fruits', palette=colors, factors=fruits))

# Customize the plot
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.yaxis.axis_label = 'Counts'
p.xaxis.axis_label = 'Fruits'
p.legend.orientation = "horizontal"
p.legend.location = "top_center"

# Show the plot
show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1311">Loading BokehJS ...</span>
#     </div>
#   <div id="333b4a37-a691-4f8a-963a-1aa11f49cef2" data-root-id="p1315" style="display: contents;"></div>

# %%
# 4. Create a Bokeh histogram to visualize the distribution of the given data.
'''
data_hist = np.random.randn(1000)
hist, edges = np.histogram(data_hist, bins=30)
'''

import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource

# Enable the output to show in the notebook (if using a notebook)
output_notebook()

# Generate dataset
data_hist = np.random.randn(1000)
hist, edges = np.histogram(data_hist, bins=30)

# Create a ColumnDataSource from the histogram data
source = ColumnDataSource(data=dict(
    top=hist,
    left=edges[:-1],
    right=edges[1:]
))

# Create a Bokeh plot
p = figure(title="Histogram of Normally Distributed Data", 
           x_axis_label='Value', 
           y_axis_label='Frequency', 
           height=400, width=800)

# Add quad glyphs to create the histogram
p.quad(top='top', bottom=0, left='left', right='right', source=source, fill_color="navy", line_color="white", alpha=0.5)

# Show the plot
show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1469">Loading BokehJS ...</span>
#     </div>
#   <div id="b2ad921d-14f7-41a0-b779-5ae06a47a83e" data-root-id="p1473" style="display: contents;"></div>

# %%
# 5. Create a Bokeh heatmap using the provided dataset.
'''
data_heatmap = np.random.rand(10, 10)
x = np.linspace(0, 1, 10)
y = np.linspace(0, 1, 10)
xx, yy = np.meshgrid(x, y)
'''

import numpy as np
import pandas as pd
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.transform import linear_cmap
from bokeh.models import ColumnDataSource, ColorBar
from bokeh.layouts import layout
from bokeh.palettes import Viridis256

# Enable the output to show in the notebook (if using a notebook)
output_notebook()

# Generate dataset
data_heatmap = np.random.rand(10, 10)
x = np.linspace(0, 1, 10)
y = np.linspace(0, 1, 10)
xx, yy = np.meshgrid(x, y)

# Flatten the arrays and create a DataFrame
data = {
    'x': xx.flatten(),
    'y': yy.flatten(),
    'value': data_heatmap.flatten()
}
df = pd.DataFrame(data)

# Create a ColumnDataSource from the DataFrame
source = ColumnDataSource(df)

# Create a Bokeh plot
p = figure(title="Heatmap", x_axis_label='X', y_axis_label='Y', 
           x_range=(0, 1), y_range=(0, 1),
           toolbar_location=None, tools="")

# Add a quad glyph to create the heatmap
mapper = linear_cmap(field_name='value', palette=Viridis256, low=min(df['value']), high=max(df['value']))
p.rect(x='x', y='y', width=0.1, height=0.1, source=source, line_color=None, fill_color=mapper)

# Add a color bar
color_bar = ColorBar(color_mapper=mapper['transform'], width=8, location=(0,0))
p.add_layout(color_bar, 'right')

# Show the plot
show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1648">Loading BokehJS ...</span>
#     </div>
#   <div id="ec4ae1dc-e179-4614-a39b-5fa26c5d618e" data-root-id="p1652" style="display: contents;"></div>
